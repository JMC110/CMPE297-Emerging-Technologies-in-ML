# %% [markdown]
# Colab link- https://colab.research.google.com/drive/16GfWNsZ_IUrj_OqPoespErhySIujJHNm?usp=sharing

# %%
pip install -r requirements.txt
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 7.5MB/s
# Collecting numpy==1.16.2
#   Downloading https://files.pythonhosted.org/packages/35/d5/4f8410ac303e690144f0a0603c4b8fd3b986feb2749c435f7cdbb288f17e/numpy-1.16.2-cp36-cp36m-manylinux1_x86_64.whl (17.3MB)
#      |████████████████████████████████| 17.3MB 172kB/s
# Collecting pandas==0.23.4
#   Downloading https://files.pythonhosted.org/packages/e1/d8/feeb346d41f181e83fba45224ab14a8d8af019b48af742e047f3845d8cff/pandas-0.23.4-cp36-cp36m-manylinux1_x86_64.whl (8.9MB)
#      |████████████████████████████████| 8.9MB 45.9MB/s
# Collecting scikit-learn==0.20.0
#   Downloading https://files.pythonhosted.org/packages/0c/b2/05be9b6da9ae4a4c54f537be22e95833f722742a02b1e355fdc09363877c/scikit_learn-0.20.0-cp36-cp36m-manylinux1_x86_64.whl (5.3MB)
#      |████████████████████████████████| 5.3MB 53.9MB/s
# Collecting tensorflow==1.15.4
#   Downloading https://files.pythonhosted.org/packages/8e/64/7a19837dd54d3f53b1ce5ae346ab401dde9678e8f233220317000bfdb3e2/tensorflow-1.15.4-cp36-cp36m-manylinux2010_x86_64.whl (110.5MB)
#      |████████████████████████████████| 110.5MB 27kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 1)) (3.13)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 8.3MB/s
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.2.4->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.4->-r requirements.txt (line 3)) (2.8.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas==0.23.4->-r requirements.txt (line 3)) (2018.9)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (3.3.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (0.8.1)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading https://files.pythonhosted.org/packages/1e/e9/d3d747a97f7188f48aa5eda486907f3b345cd409f0a0850468ba867db246/tensorboard-1.15.0-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 44.8MB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (0.35.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (0.2.0)
# Collecting tensorflow-estimator==1.15.1
#   Downloading https://files.pythonhosted.org/packages/de/62/2ee9cd74c9fa2fa450877847ba560b260f5d0fb70ee0595203082dafcc9d/tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503kB)
#      |████████████████████████████████| 512kB 49.9MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (1.33.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (1.12.1)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.15.4->-r requirements.txt (line 5)) (3.12.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->-r requirements.txt (line 5)) (50.3.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->-r requirements.txt (line 5)) (3.3.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.4->-r requirements.txt (line 5)) (3.3.1)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=7dde5473fb3a7cf18ccb407383f42f6de345e0533a707071981f2621fc4c423e
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: xarray 0.15.1 has requirement pandas>=0.25, but you'll have pandas 0.23.4 which is incompatible.
# ERROR: umap-learn 0.4.6 has requirement numpy>=1.17, but you'll have numpy 1.16.2 which is incompatible.
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: plotnine 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.23.4 which is incompatible.
# ERROR: mizani 0.6.0 has requirement pandas>=0.25.0, but you'll have pandas 0.23.4 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.1.0; python_version >= "3.0", but you'll have pandas 0.23.4 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement pandas>=1.0.4, but you'll have pandas 0.23.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy, keras-applications, keras, pandas, scikit-learn, tensorboard, tensorflow-estimator, gast, tensorflow
#   Found existing installation: numpy 1.18.5
#     Uninstalling numpy-1.18.5:
#       Successfully uninstalled numpy-1.18.5
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
#   Found existing installation: pandas 1.1.3
#     Uninstalling pandas-1.1.3:
#       Successfully uninstalled pandas-1.1.3
#   Found existing installation: scikit-learn 0.22.2.post1
#     Uninstalling scikit-learn-0.22.2.post1:
#       Successfully uninstalled scikit-learn-0.22.2.post1
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed gast-0.2.2 keras-2.2.4 keras-applications-1.0.8 numpy-1.16.2 pandas-0.23.4 scikit-learn-0.20.0 tensorboard-1.15.0 tensorflow-1.15.4 tensorflow-estimator-1.15.1

# %%
import random
import pandas as pd
import numpy as np
import tensorflow as tf
from keras import backend as K
from keras.optimizers import Adam
from keras.initializers import VarianceScaling
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import to_categorical
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score
from mmoe import MMoE
# Out:
# Using TensorFlow backend.

# %%
SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.set_random_seed(SEED)
tf_session = tf.Session(graph=tf.get_default_graph())
K.set_session(tf_session)

# %%
# Simple callback to print out ROC-AUC
class ROCCallback(Callback):
    def __init__(self, training_data, validation_data, test_data):
        self.train_X = training_data[0]
        self.train_Y = training_data[1]
        self.validation_X = validation_data[0]
        self.validation_Y = validation_data[1]
        self.test_X = test_data[0]
        self.test_Y = test_data[1]

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        train_prediction = self.model.predict(self.train_X)
        validation_prediction = self.model.predict(self.validation_X)
        test_prediction = self.model.predict(self.test_X)

        # Iterate through each task and output their ROC-AUC across different datasets
        for index, output_name in enumerate(self.model.output_names):
            train_roc_auc = roc_auc_score(self.train_Y[index], train_prediction[index])
            validation_roc_auc = roc_auc_score(self.validation_Y[index], validation_prediction[index])
            test_roc_auc = roc_auc_score(self.test_Y[index], test_prediction[index])
            print(
                'ROC-AUC-{}-Train: {} ROC-AUC-{}-Validation: {} ROC-AUC-{}-Test: {}'.format(
                    output_name, round(train_roc_auc, 4),
                    output_name, round(validation_roc_auc, 4),
                    output_name, round(test_roc_auc, 4)
                )
            )

        return

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return

# %%
def data_preparation():
    # The column names are from
    # https://www2.1010data.com/documentationcenter/prod/Tutorials/MachineLearningExamples/CensusIncomeDataSet.html
    column_names = ['age', 'class_worker', 'det_ind_code', 'det_occ_code', 'education', 'wage_per_hour', 'hs_college',
                    'marital_stat', 'major_ind_code', 'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member',
                    'unemp_reason', 'full_or_part_emp', 'capital_gains', 'capital_losses', 'stock_dividends',
                    'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat', 'det_hh_summ',
                    'instance_weight', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                    'num_emp', 'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                    'own_or_self', 'vet_question', 'vet_benefits', 'weeks_worked', 'year', 'income_50k']

    # Load the dataset in Pandas
    train_df = pd.read_csv(
        '/content/census-income.data.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )
    other_df = pd.read_csv(
        '/content/census-income.test.gz',
        delimiter=',',
        header=None,
        index_col=None,
        names=column_names
    )

    # First group of tasks according to the paper
    label_columns = ['income_50k', 'marital_stat']

    # One-hot encoding categorical columns
    categorical_columns = ['class_worker', 'det_ind_code', 'det_occ_code', 'education', 'hs_college', 'major_ind_code',
                           'major_occ_code', 'race', 'hisp_origin', 'sex', 'union_member', 'unemp_reason',
                           'full_or_part_emp', 'tax_filer_stat', 'region_prev_res', 'state_prev_res', 'det_hh_fam_stat',
                           'det_hh_summ', 'mig_chg_msa', 'mig_chg_reg', 'mig_move_reg', 'mig_same', 'mig_prev_sunbelt',
                           'fam_under_18', 'country_father', 'country_mother', 'country_self', 'citizenship',
                           'vet_question']
    train_raw_labels = train_df[label_columns]
    other_raw_labels = other_df[label_columns]
    transformed_train = pd.get_dummies(train_df.drop(label_columns, axis=1), columns=categorical_columns)
    transformed_other = pd.get_dummies(other_df.drop(label_columns, axis=1), columns=categorical_columns)

    # Filling the missing column in the other set
    transformed_other['det_hh_fam_stat_ Grandchild <18 ever marr not in subfamily'] = 0

    # One-hot encoding categorical labels
    train_income = to_categorical((train_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    train_marital = to_categorical((train_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)
    other_income = to_categorical((other_raw_labels.income_50k == ' 50000+.').astype(int), num_classes=2)
    other_marital = to_categorical((other_raw_labels.marital_stat == ' Never married').astype(int), num_classes=2)

    dict_outputs = {
        'income': train_income.shape[1],
        'marital': train_marital.shape[1]
    }
    dict_train_labels = {
        'income': train_income,
        'marital': train_marital
    }
    dict_other_labels = {
        'income': other_income,
        'marital': other_marital
    }
    output_info = [(dict_outputs[key], key) for key in sorted(dict_outputs.keys())]

    # Split the other dataset into 1:1 validation to test according to the paper
    validation_indices = transformed_other.sample(frac=0.5, replace=False, random_state=SEED).index
    test_indices = list(set(transformed_other.index) - set(validation_indices))
    validation_data = transformed_other.iloc[validation_indices]
    validation_label = [dict_other_labels[key][validation_indices] for key in sorted(dict_other_labels.keys())]
    test_data = transformed_other.iloc[test_indices]
    test_label = [dict_other_labels[key][test_indices] for key in sorted(dict_other_labels.keys())]
    train_data = transformed_train
    train_label = [dict_train_labels[key] for key in sorted(dict_train_labels.keys())]

    return train_data, train_label, validation_data, validation_label, test_data, test_label, output_info


def main():
    # Load the data
    train_data, train_label, validation_data, validation_label, test_data, test_label, output_info = data_preparation()
    num_features = train_data.shape[1]

    print('Training data shape = {}'.format(train_data.shape))
    print('Validation data shape = {}'.format(validation_data.shape))
    print('Test data shape = {}'.format(test_data.shape))

    # Set up the input layer
    input_layer = Input(shape=(num_features,))

    # Set up MMoE layer
    mmoe_layers = MMoE(
        units=4,
        num_experts=8,
        num_tasks=2
    )(input_layer)

    output_layers = []

    # Build tower layer from MMoE layer
    for index, task_layer in enumerate(mmoe_layers):
        tower_layer = Dense(
            units=8,
            activation='relu',
            kernel_initializer=VarianceScaling())(task_layer)
        output_layer = Dense(
            units=output_info[index][0],
            name=output_info[index][1],
            activation='softmax',
            kernel_initializer=VarianceScaling())(tower_layer)
        output_layers.append(output_layer)

    # Compile model
    model = Model(inputs=[input_layer], outputs=output_layers)
    adam_optimizer = Adam()
    model.compile(
        loss={'income': 'binary_crossentropy', 'marital': 'binary_crossentropy'},
        optimizer=adam_optimizer,
        metrics=['accuracy']
    )

    # Print out model architecture summary
    model.summary()

    # Train the model
    model.fit(
        x=train_data,
        y=train_label,
        validation_data=(validation_data, validation_label),
        callbacks=[
            ROCCallback(
                training_data=(train_data, train_label),
                validation_data=(validation_data, validation_label),
                test_data=(test_data, test_label)
            )
        ],
        epochs=100
    )


if __name__ == '__main__':
    main()
# Out:
# Training data shape = (199523, 499)
# Validation data shape = (49881, 499)
# Test data shape = (49881, 499)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 499)          0
# __________________________________________________________________________________________________
# m_mo_e_1 (MMoE)                 [(None, 4), (None, 4 24000       input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            40          m_mo_e_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            40          m_mo_e_1[0][1]
# __________________________________________________________________________________________________
# income (Dense)                  (None, 2)            18          dense_1[0][0]
# __________________________________________________________________________________________________
# marital (Dense)                 (None, 2)            18          dense_2[0][0]
# ==================================================================================================
# Total params: 24,116
# Trainable params: 24,116
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 199523 samples, validate on 49881 samples
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.4606 - income_loss: 0.2334 - marital_loss: 0.2272 - income_acc: 0.9346 - marital_acc: 0.9181 - val_loss: 0.4072 - val_income_loss: 0.1618 - val_marital_loss: 0.2454 - val_income_acc: 0.9378 - val_marital_acc: 0.9041
# ROC-AUC-income-Train: 0.893 ROC-AUC-income-Validation: 0.9004 ROC-AUC-income-Test: 0.9001
# ROC-AUC-marital-Train: 0.9876 ROC-AUC-marital-Validation: 0.9723 ROC-AUC-marital-Test: 0.9724
# Epoch 2/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2924 - income_loss: 0.1542 - marital_loss: 0.1382 - income_acc: 0.9379 - marital_acc: 0.9429 - val_loss: 0.3778 - val_income_loss: 0.1532 - val_marital_loss: 0.2246 - val_income_acc: 0.9378 - val_marital_acc: 0.9170
# ROC-AUC-income-Train: 0.9048 ROC-AUC-income-Validation: 0.9091 ROC-AUC-income-Test: 0.9093
# ROC-AUC-marital-Train: 0.985 ROC-AUC-marital-Validation: 0.9706 ROC-AUC-marital-Test: 0.9699
# Epoch 3/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2818 - income_loss: 0.1503 - marital_loss: 0.1315 - income_acc: 0.9379 - marital_acc: 0.9450 - val_loss: 0.4632 - val_income_loss: 0.1632 - val_marital_loss: 0.3000 - val_income_acc: 0.9378 - val_marital_acc: 0.8719
# ROC-AUC-income-Train: 0.9283 ROC-AUC-income-Validation: 0.9257 ROC-AUC-income-Test: 0.9259
# ROC-AUC-marital-Train: 0.9857 ROC-AUC-marital-Validation: 0.9648 ROC-AUC-marital-Test: 0.9639
# Epoch 4/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2757 - income_loss: 0.1456 - marital_loss: 0.1300 - income_acc: 0.9379 - marital_acc: 0.9456 - val_loss: 0.3851 - val_income_loss: 0.1640 - val_marital_loss: 0.2210 - val_income_acc: 0.9378 - val_marital_acc: 0.9142
# ROC-AUC-income-Train: 0.9281 ROC-AUC-income-Validation: 0.9252 ROC-AUC-income-Test: 0.9235
# ROC-AUC-marital-Train: 0.9896 ROC-AUC-marital-Validation: 0.9743 ROC-AUC-marital-Test: 0.9737
# Epoch 5/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2701 - income_loss: 0.1445 - marital_loss: 0.1255 - income_acc: 0.9379 - marital_acc: 0.9471 - val_loss: 0.3680 - val_income_loss: 0.1629 - val_marital_loss: 0.2051 - val_income_acc: 0.9378 - val_marital_acc: 0.9161
# ROC-AUC-income-Train: 0.9225 ROC-AUC-income-Validation: 0.9185 ROC-AUC-income-Test: 0.9186
# ROC-AUC-marital-Train: 0.9901 ROC-AUC-marital-Validation: 0.9745 ROC-AUC-marital-Test: 0.9737
# Epoch 6/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2663 - income_loss: 0.1429 - marital_loss: 0.1234 - income_acc: 0.9379 - marital_acc: 0.9478 - val_loss: 0.3816 - val_income_loss: 0.1537 - val_marital_loss: 0.2279 - val_income_acc: 0.9378 - val_marital_acc: 0.9142
# ROC-AUC-income-Train: 0.9378 ROC-AUC-income-Validation: 0.9351 ROC-AUC-income-Test: 0.9335
# ROC-AUC-marital-Train: 0.9893 ROC-AUC-marital-Validation: 0.9729 ROC-AUC-marital-Test: 0.9722
# Epoch 7/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2654 - income_loss: 0.1414 - marital_loss: 0.1240 - income_acc: 0.9379 - marital_acc: 0.9479 - val_loss: 0.3692 - val_income_loss: 0.1503 - val_marital_loss: 0.2189 - val_income_acc: 0.9378 - val_marital_acc: 0.9086
# ROC-AUC-income-Train: 0.9283 ROC-AUC-income-Validation: 0.925 ROC-AUC-income-Test: 0.9234
# ROC-AUC-marital-Train: 0.9903 ROC-AUC-marital-Validation: 0.9724 ROC-AUC-marital-Test: 0.9712
# Epoch 8/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2628 - income_loss: 0.1383 - marital_loss: 0.1246 - income_acc: 0.9384 - marital_acc: 0.9484 - val_loss: 0.3896 - val_income_loss: 0.1679 - val_marital_loss: 0.2217 - val_income_acc: 0.9413 - val_marital_acc: 0.9175
# ROC-AUC-income-Train: 0.9319 ROC-AUC-income-Validation: 0.9298 ROC-AUC-income-Test: 0.9293
# ROC-AUC-marital-Train: 0.9907 ROC-AUC-marital-Validation: 0.9737 ROC-AUC-marital-Test: 0.9729
# Epoch 9/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2597 - income_loss: 0.1403 - marital_loss: 0.1194 - income_acc: 0.9379 - marital_acc: 0.9492 - val_loss: 0.4252 - val_income_loss: 0.1760 - val_marital_loss: 0.2493 - val_income_acc: 0.9378 - val_marital_acc: 0.9052
# ROC-AUC-income-Train: 0.9388 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9345
# ROC-AUC-marital-Train: 0.9867 ROC-AUC-marital-Validation: 0.9664 ROC-AUC-marital-Test: 0.9655
# Epoch 10/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2521 - income_loss: 0.1381 - marital_loss: 0.1141 - income_acc: 0.9394 - marital_acc: 0.9510 - val_loss: 0.3734 - val_income_loss: 0.1607 - val_marital_loss: 0.2127 - val_income_acc: 0.9369 - val_marital_acc: 0.9150
# ROC-AUC-income-Train: 0.9315 ROC-AUC-income-Validation: 0.927 ROC-AUC-income-Test: 0.9257
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9735 ROC-AUC-marital-Test: 0.9726
# Epoch 11/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2585 - income_loss: 0.1365 - marital_loss: 0.1220 - income_acc: 0.9412 - marital_acc: 0.9523 - val_loss: 0.3915 - val_income_loss: 0.1797 - val_marital_loss: 0.2118 - val_income_acc: 0.9457 - val_marital_acc: 0.9176
# ROC-AUC-income-Train: 0.9407 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9732 ROC-AUC-marital-Test: 0.9724
# Epoch 12/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2451 - income_loss: 0.1364 - marital_loss: 0.1087 - income_acc: 0.9406 - marital_acc: 0.9535 - val_loss: 0.4000 - val_income_loss: 0.1778 - val_marital_loss: 0.2222 - val_income_acc: 0.9322 - val_marital_acc: 0.9037
# ROC-AUC-income-Train: 0.9278 ROC-AUC-income-Validation: 0.923 ROC-AUC-income-Test: 0.9233
# ROC-AUC-marital-Train: 0.9931 ROC-AUC-marital-Validation: 0.9725 ROC-AUC-marital-Test: 0.9718
# Epoch 13/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2454 - income_loss: 0.1363 - marital_loss: 0.1090 - income_acc: 0.9405 - marital_acc: 0.9530 - val_loss: 0.3898 - val_income_loss: 0.1791 - val_marital_loss: 0.2106 - val_income_acc: 0.9435 - val_marital_acc: 0.9174
# ROC-AUC-income-Train: 0.9356 ROC-AUC-income-Validation: 0.9328 ROC-AUC-income-Test: 0.9314
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9745 ROC-AUC-marital-Test: 0.9735
# Epoch 14/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2451 - income_loss: 0.1347 - marital_loss: 0.1104 - income_acc: 0.9434 - marital_acc: 0.9534 - val_loss: 0.4186 - val_income_loss: 0.1626 - val_marital_loss: 0.2560 - val_income_acc: 0.9439 - val_marital_acc: 0.9104
# ROC-AUC-income-Train: 0.9393 ROC-AUC-income-Validation: 0.935 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.9925 ROC-AUC-marital-Validation: 0.9666 ROC-AUC-marital-Test: 0.9651
# Epoch 15/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2413 - income_loss: 0.1350 - marital_loss: 0.1063 - income_acc: 0.9436 - marital_acc: 0.9541 - val_loss: 0.4312 - val_income_loss: 0.1691 - val_marital_loss: 0.2620 - val_income_acc: 0.9340 - val_marital_acc: 0.9095
# ROC-AUC-income-Train: 0.932 ROC-AUC-income-Validation: 0.9262 ROC-AUC-income-Test: 0.9263
# ROC-AUC-marital-Train: 0.9883 ROC-AUC-marital-Validation: 0.9646 ROC-AUC-marital-Test: 0.9636
# Epoch 16/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2517 - income_loss: 0.1357 - marital_loss: 0.1160 - income_acc: 0.9418 - marital_acc: 0.9544 - val_loss: 0.4237 - val_income_loss: 0.1595 - val_marital_loss: 0.2642 - val_income_acc: 0.9378 - val_marital_acc: 0.8778
# ROC-AUC-income-Train: 0.9343 ROC-AUC-income-Validation: 0.9308 ROC-AUC-income-Test: 0.9296
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9689 ROC-AUC-marital-Test: 0.9678
# Epoch 17/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2428 - income_loss: 0.1363 - marital_loss: 0.1065 - income_acc: 0.9411 - marital_acc: 0.9548 - val_loss: 0.4777 - val_income_loss: 0.1572 - val_marital_loss: 0.3205 - val_income_acc: 0.9450 - val_marital_acc: 0.8708
# ROC-AUC-income-Train: 0.9397 ROC-AUC-income-Validation: 0.9366 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.9882 ROC-AUC-marital-Validation: 0.9631 ROC-AUC-marital-Test: 0.9617
# Epoch 18/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2417 - income_loss: 0.1338 - marital_loss: 0.1079 - income_acc: 0.9452 - marital_acc: 0.9541 - val_loss: 0.4134 - val_income_loss: 0.1662 - val_marital_loss: 0.2473 - val_income_acc: 0.9437 - val_marital_acc: 0.9018
# ROC-AUC-income-Train: 0.9375 ROC-AUC-income-Validation: 0.9338 ROC-AUC-income-Test: 0.9338
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9688 ROC-AUC-marital-Test: 0.9676
# Epoch 19/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2407 - income_loss: 0.1351 - marital_loss: 0.1056 - income_acc: 0.9460 - marital_acc: 0.9552 - val_loss: 0.4166 - val_income_loss: 0.1494 - val_marital_loss: 0.2673 - val_income_acc: 0.9470 - val_marital_acc: 0.8834
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.9379 ROC-AUC-income-Test: 0.9369
# ROC-AUC-marital-Train: 0.9926 ROC-AUC-marital-Validation: 0.9642 ROC-AUC-marital-Test: 0.963
# Epoch 20/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2361 - income_loss: 0.1330 - marital_loss: 0.1032 - income_acc: 0.9458 - marital_acc: 0.9553 - val_loss: 0.4731 - val_income_loss: 0.1678 - val_marital_loss: 0.3053 - val_income_acc: 0.9466 - val_marital_acc: 0.8653
# ROC-AUC-income-Train: 0.9414 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.937
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9638 ROC-AUC-marital-Test: 0.9624
# Epoch 21/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2365 - income_loss: 0.1320 - marital_loss: 0.1044 - income_acc: 0.9467 - marital_acc: 0.9551 - val_loss: 0.4158 - val_income_loss: 0.1645 - val_marital_loss: 0.2513 - val_income_acc: 0.9457 - val_marital_acc: 0.9058
# ROC-AUC-income-Train: 0.9441 ROC-AUC-income-Validation: 0.9402 ROC-AUC-income-Test: 0.9392
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9657 ROC-AUC-marital-Test: 0.9642
# Epoch 22/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2349 - income_loss: 0.1318 - marital_loss: 0.1030 - income_acc: 0.9465 - marital_acc: 0.9552 - val_loss: 0.4380 - val_income_loss: 0.1836 - val_marital_loss: 0.2544 - val_income_acc: 0.9467 - val_marital_acc: 0.9002
# ROC-AUC-income-Train: 0.9383 ROC-AUC-income-Validation: 0.9346 ROC-AUC-income-Test: 0.9337
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9638 ROC-AUC-marital-Test: 0.9625
# Epoch 23/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2337 - income_loss: 0.1322 - marital_loss: 0.1014 - income_acc: 0.9465 - marital_acc: 0.9559 - val_loss: 0.4820 - val_income_loss: 0.1830 - val_marital_loss: 0.2991 - val_income_acc: 0.9461 - val_marital_acc: 0.8719
# ROC-AUC-income-Train: 0.9413 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9364
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.9602
# Epoch 24/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2342 - income_loss: 0.1323 - marital_loss: 0.1019 - income_acc: 0.9467 - marital_acc: 0.9557 - val_loss: 0.4172 - val_income_loss: 0.1603 - val_marital_loss: 0.2568 - val_income_acc: 0.9462 - val_marital_acc: 0.8946
# ROC-AUC-income-Train: 0.9423 ROC-AUC-income-Validation: 0.9382 ROC-AUC-income-Test: 0.9377
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9637
# Epoch 25/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2349 - income_loss: 0.1324 - marital_loss: 0.1024 - income_acc: 0.9481 - marital_acc: 0.9563 - val_loss: 0.4568 - val_income_loss: 0.1578 - val_marital_loss: 0.2990 - val_income_acc: 0.9465 - val_marital_acc: 0.8918
# ROC-AUC-income-Train: 0.9404 ROC-AUC-income-Validation: 0.9361 ROC-AUC-income-Test: 0.9356
# ROC-AUC-marital-Train: 0.993 ROC-AUC-marital-Validation: 0.9606 ROC-AUC-marital-Test: 0.9595
# Epoch 26/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2320 - income_loss: 0.1305 - marital_loss: 0.1015 - income_acc: 0.9479 - marital_acc: 0.9557 - val_loss: 0.4460 - val_income_loss: 0.1663 - val_marital_loss: 0.2798 - val_income_acc: 0.9455 - val_marital_acc: 0.8801
# ROC-AUC-income-Train: 0.9394 ROC-AUC-income-Validation: 0.9353 ROC-AUC-income-Test: 0.9344
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9626 ROC-AUC-marital-Test: 0.9613
# Epoch 27/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2330 - income_loss: 0.1328 - marital_loss: 0.1002 - income_acc: 0.9466 - marital_acc: 0.9558 - val_loss: 0.4603 - val_income_loss: 0.1695 - val_marital_loss: 0.2908 - val_income_acc: 0.9448 - val_marital_acc: 0.8956
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.9379
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9609 ROC-AUC-marital-Test: 0.9595
# Epoch 28/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2338 - income_loss: 0.1304 - marital_loss: 0.1034 - income_acc: 0.9481 - marital_acc: 0.9561 - val_loss: 0.4511 - val_income_loss: 0.1631 - val_marital_loss: 0.2881 - val_income_acc: 0.9435 - val_marital_acc: 0.8903
# ROC-AUC-income-Train: 0.939 ROC-AUC-income-Validation: 0.9345 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9595 ROC-AUC-marital-Test: 0.9582
# Epoch 29/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2309 - income_loss: 0.1306 - marital_loss: 0.1003 - income_acc: 0.9488 - marital_acc: 0.9567 - val_loss: 0.4976 - val_income_loss: 0.1779 - val_marital_loss: 0.3197 - val_income_acc: 0.9432 - val_marital_acc: 0.8712
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9396 ROC-AUC-income-Test: 0.9389
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.96 ROC-AUC-marital-Test: 0.9587
# Epoch 30/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2296 - income_loss: 0.1301 - marital_loss: 0.0996 - income_acc: 0.9492 - marital_acc: 0.9568 - val_loss: 0.5101 - val_income_loss: 0.1849 - val_marital_loss: 0.3252 - val_income_acc: 0.9453 - val_marital_acc: 0.8634
# ROC-AUC-income-Train: 0.9411 ROC-AUC-income-Validation: 0.936 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9577 ROC-AUC-marital-Test: 0.9561
# Epoch 31/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2299 - income_loss: 0.1298 - marital_loss: 0.1002 - income_acc: 0.9490 - marital_acc: 0.9561 - val_loss: 0.5408 - val_income_loss: 0.2257 - val_marital_loss: 0.3151 - val_income_acc: 0.9409 - val_marital_acc: 0.8759
# ROC-AUC-income-Train: 0.9272 ROC-AUC-income-Validation: 0.9192 ROC-AUC-income-Test: 0.9205
# ROC-AUC-marital-Train: 0.9933 ROC-AUC-marital-Validation: 0.9585 ROC-AUC-marital-Test: 0.9569
# Epoch 32/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2335 - income_loss: 0.1337 - marital_loss: 0.0998 - income_acc: 0.9488 - marital_acc: 0.9563 - val_loss: 0.5790 - val_income_loss: 0.1994 - val_marital_loss: 0.3796 - val_income_acc: 0.9443 - val_marital_acc: 0.8499
# ROC-AUC-income-Train: 0.9435 ROC-AUC-income-Validation: 0.9392 ROC-AUC-income-Test: 0.9383
# ROC-AUC-marital-Train: 0.9917 ROC-AUC-marital-Validation: 0.9541 ROC-AUC-marital-Test: 0.9527
# Epoch 33/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2314 - income_loss: 0.1300 - marital_loss: 0.1014 - income_acc: 0.9486 - marital_acc: 0.9566 - val_loss: 0.4904 - val_income_loss: 0.1739 - val_marital_loss: 0.3164 - val_income_acc: 0.9424 - val_marital_acc: 0.8708
# ROC-AUC-income-Train: 0.9386 ROC-AUC-income-Validation: 0.9335 ROC-AUC-income-Test: 0.9328
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9603 ROC-AUC-marital-Test: 0.9589
# Epoch 34/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2307 - income_loss: 0.1310 - marital_loss: 0.0997 - income_acc: 0.9486 - marital_acc: 0.9569 - val_loss: 0.4848 - val_income_loss: 0.1880 - val_marital_loss: 0.2968 - val_income_acc: 0.9455 - val_marital_acc: 0.8708
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.938 ROC-AUC-income-Test: 0.9373
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9592 ROC-AUC-marital-Test: 0.9578
# Epoch 35/100
# 199523/199523 [==============================] - 14s 70us/step - loss: 0.2291 - income_loss: 0.1289 - marital_loss: 0.1002 - income_acc: 0.9492 - marital_acc: 0.9568 - val_loss: 0.4896 - val_income_loss: 0.1890 - val_marital_loss: 0.3006 - val_income_acc: 0.9444 - val_marital_acc: 0.8978
# ROC-AUC-income-Train: 0.944 ROC-AUC-income-Validation: 0.9389 ROC-AUC-income-Test: 0.9385
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9594 ROC-AUC-marital-Test: 0.9581
# Epoch 36/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2305 - income_loss: 0.1301 - marital_loss: 0.1004 - income_acc: 0.9492 - marital_acc: 0.9568 - val_loss: 0.4960 - val_income_loss: 0.1857 - val_marital_loss: 0.3103 - val_income_acc: 0.9467 - val_marital_acc: 0.8644
# ROC-AUC-income-Train: 0.9403 ROC-AUC-income-Validation: 0.9363 ROC-AUC-income-Test: 0.9352
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9589 ROC-AUC-marital-Test: 0.9574
# Epoch 37/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2300 - income_loss: 0.1301 - marital_loss: 0.1000 - income_acc: 0.9490 - marital_acc: 0.9568 - val_loss: 0.5259 - val_income_loss: 0.1870 - val_marital_loss: 0.3389 - val_income_acc: 0.9442 - val_marital_acc: 0.8661
# ROC-AUC-income-Train: 0.943 ROC-AUC-income-Validation: 0.9367 ROC-AUC-income-Test: 0.9365
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9568 ROC-AUC-marital-Test: 0.9552
# Epoch 38/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2294 - income_loss: 0.1300 - marital_loss: 0.0994 - income_acc: 0.9487 - marital_acc: 0.9571 - val_loss: 0.5123 - val_income_loss: 0.1741 - val_marital_loss: 0.3383 - val_income_acc: 0.9455 - val_marital_acc: 0.8623
# ROC-AUC-income-Train: 0.9433 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9374
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9557 ROC-AUC-marital-Test: 0.9539
# Epoch 39/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2286 - income_loss: 0.1297 - marital_loss: 0.0989 - income_acc: 0.9483 - marital_acc: 0.9564 - val_loss: 0.5198 - val_income_loss: 0.1720 - val_marital_loss: 0.3478 - val_income_acc: 0.9416 - val_marital_acc: 0.8644
# ROC-AUC-income-Train: 0.9426 ROC-AUC-income-Validation: 0.9352 ROC-AUC-income-Test: 0.9355
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.955 ROC-AUC-marital-Test: 0.9533
# Epoch 40/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2294 - income_loss: 0.1308 - marital_loss: 0.0986 - income_acc: 0.9484 - marital_acc: 0.9563 - val_loss: 0.5445 - val_income_loss: 0.1685 - val_marital_loss: 0.3760 - val_income_acc: 0.9455 - val_marital_acc: 0.8592
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9393 ROC-AUC-income-Test: 0.9384
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9533 ROC-AUC-marital-Test: 0.9518
# Epoch 41/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2296 - income_loss: 0.1304 - marital_loss: 0.0992 - income_acc: 0.9482 - marital_acc: 0.9565 - val_loss: 0.4848 - val_income_loss: 0.1860 - val_marital_loss: 0.2989 - val_income_acc: 0.9437 - val_marital_acc: 0.8830
# ROC-AUC-income-Train: 0.9438 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.96 ROC-AUC-marital-Test: 0.9585
# Epoch 42/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2278 - income_loss: 0.1289 - marital_loss: 0.0989 - income_acc: 0.9499 - marital_acc: 0.9568 - val_loss: 0.5018 - val_income_loss: 0.1927 - val_marital_loss: 0.3091 - val_income_acc: 0.9446 - val_marital_acc: 0.8917
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9385
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9587 ROC-AUC-marital-Test: 0.9572
# Epoch 43/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2279 - income_loss: 0.1289 - marital_loss: 0.0990 - income_acc: 0.9496 - marital_acc: 0.9568 - val_loss: 0.4661 - val_income_loss: 0.1754 - val_marital_loss: 0.2907 - val_income_acc: 0.9435 - val_marital_acc: 0.8922
# ROC-AUC-income-Train: 0.9396 ROC-AUC-income-Validation: 0.9344 ROC-AUC-income-Test: 0.9335
# ROC-AUC-marital-Train: 0.9929 ROC-AUC-marital-Validation: 0.9603 ROC-AUC-marital-Test: 0.9591
# Epoch 44/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2282 - income_loss: 0.1300 - marital_loss: 0.0982 - income_acc: 0.9501 - marital_acc: 0.9573 - val_loss: 0.5546 - val_income_loss: 0.2139 - val_marital_loss: 0.3406 - val_income_acc: 0.9428 - val_marital_acc: 0.8733
# ROC-AUC-income-Train: 0.9435 ROC-AUC-income-Validation: 0.937 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9575 ROC-AUC-marital-Test: 0.9559
# Epoch 45/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2297 - income_loss: 0.1302 - marital_loss: 0.0995 - income_acc: 0.9496 - marital_acc: 0.9569 - val_loss: 0.6421 - val_income_loss: 0.2941 - val_marital_loss: 0.3480 - val_income_acc: 0.9387 - val_marital_acc: 0.8654
# ROC-AUC-income-Train: 0.8652 ROC-AUC-income-Validation: 0.8497 ROC-AUC-income-Test: 0.8505
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9559 ROC-AUC-marital-Test: 0.9543
# Epoch 46/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2291 - income_loss: 0.1297 - marital_loss: 0.0994 - income_acc: 0.9501 - marital_acc: 0.9570 - val_loss: 0.4676 - val_income_loss: 0.1852 - val_marital_loss: 0.2823 - val_income_acc: 0.9446 - val_marital_acc: 0.8938
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9386
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9615 ROC-AUC-marital-Test: 0.9603
# Epoch 47/100
# 199523/199523 [==============================] - 14s 72us/step - loss: 0.2259 - income_loss: 0.1279 - marital_loss: 0.0980 - income_acc: 0.9499 - marital_acc: 0.9574 - val_loss: 0.4724 - val_income_loss: 0.1950 - val_marital_loss: 0.2774 - val_income_acc: 0.9450 - val_marital_acc: 0.8933
# ROC-AUC-income-Train: 0.937 ROC-AUC-income-Validation: 0.9316 ROC-AUC-income-Test: 0.9303
# ROC-AUC-marital-Train: 0.9927 ROC-AUC-marital-Validation: 0.9604 ROC-AUC-marital-Test: 0.9597
# Epoch 48/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2275 - income_loss: 0.1293 - marital_loss: 0.0982 - income_acc: 0.9491 - marital_acc: 0.9569 - val_loss: 0.4930 - val_income_loss: 0.1773 - val_marital_loss: 0.3157 - val_income_acc: 0.9438 - val_marital_acc: 0.8894
# ROC-AUC-income-Train: 0.9401 ROC-AUC-income-Validation: 0.9345 ROC-AUC-income-Test: 0.9345
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9588 ROC-AUC-marital-Test: 0.9571
# Epoch 49/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2271 - income_loss: 0.1289 - marital_loss: 0.0982 - income_acc: 0.9500 - marital_acc: 0.9573 - val_loss: 0.4826 - val_income_loss: 0.1770 - val_marital_loss: 0.3057 - val_income_acc: 0.9457 - val_marital_acc: 0.8834
# ROC-AUC-income-Train: 0.943 ROC-AUC-income-Validation: 0.9375 ROC-AUC-income-Test: 0.9366
# ROC-AUC-marital-Train: 0.9932 ROC-AUC-marital-Validation: 0.9571 ROC-AUC-marital-Test: 0.9554
# Epoch 50/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2268 - income_loss: 0.1297 - marital_loss: 0.0972 - income_acc: 0.9499 - marital_acc: 0.9576 - val_loss: 0.5180 - val_income_loss: 0.1727 - val_marital_loss: 0.3453 - val_income_acc: 0.9439 - val_marital_acc: 0.8794
# ROC-AUC-income-Train: 0.9405 ROC-AUC-income-Validation: 0.9342 ROC-AUC-income-Test: 0.9334
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9574 ROC-AUC-marital-Test: 0.9558
# Epoch 51/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2312 - income_loss: 0.1313 - marital_loss: 0.1000 - income_acc: 0.9499 - marital_acc: 0.9573 - val_loss: 0.4966 - val_income_loss: 0.1792 - val_marital_loss: 0.3174 - val_income_acc: 0.9451 - val_marital_acc: 0.8751
# ROC-AUC-income-Train: 0.9417 ROC-AUC-income-Validation: 0.936 ROC-AUC-income-Test: 0.9354
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.958 ROC-AUC-marital-Test: 0.9562
# Epoch 52/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2247 - income_loss: 0.1270 - marital_loss: 0.0977 - income_acc: 0.9508 - marital_acc: 0.9575 - val_loss: 0.4977 - val_income_loss: 0.1842 - val_marital_loss: 0.3135 - val_income_acc: 0.9454 - val_marital_acc: 0.8781
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9394 ROC-AUC-income-Test: 0.9386
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9572 ROC-AUC-marital-Test: 0.9554
# Epoch 53/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2267 - income_loss: 0.1288 - marital_loss: 0.0979 - income_acc: 0.9505 - marital_acc: 0.9572 - val_loss: 0.4593 - val_income_loss: 0.1756 - val_marital_loss: 0.2837 - val_income_acc: 0.9445 - val_marital_acc: 0.8948
# ROC-AUC-income-Train: 0.9427 ROC-AUC-income-Validation: 0.937 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9596
# Epoch 54/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2276 - income_loss: 0.1293 - marital_loss: 0.0983 - income_acc: 0.9503 - marital_acc: 0.9568 - val_loss: 0.4876 - val_income_loss: 0.1902 - val_marital_loss: 0.2973 - val_income_acc: 0.9426 - val_marital_acc: 0.8891
# ROC-AUC-income-Train: 0.9408 ROC-AUC-income-Validation: 0.933 ROC-AUC-income-Test: 0.9333
# ROC-AUC-marital-Train: 0.9936 ROC-AUC-marital-Validation: 0.9602 ROC-AUC-marital-Test: 0.9586
# Epoch 55/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2274 - income_loss: 0.1304 - marital_loss: 0.0970 - income_acc: 0.9504 - marital_acc: 0.9570 - val_loss: 0.4916 - val_income_loss: 0.1680 - val_marital_loss: 0.3236 - val_income_acc: 0.9456 - val_marital_acc: 0.8956
# ROC-AUC-income-Train: 0.9422 ROC-AUC-income-Validation: 0.9366 ROC-AUC-income-Test: 0.9358
# ROC-AUC-marital-Train: 0.992 ROC-AUC-marital-Validation: 0.9585 ROC-AUC-marital-Test: 0.957
# Epoch 56/100
# 199523/199523 [==============================] - 14s 73us/step - loss: 0.2265 - income_loss: 0.1282 - marital_loss: 0.0983 - income_acc: 0.9508 - marital_acc: 0.9576 - val_loss: 0.5316 - val_income_loss: 0.1857 - val_marital_loss: 0.3460 - val_income_acc: 0.9450 - val_marital_acc: 0.8663
# ROC-AUC-income-Train: 0.9451 ROC-AUC-income-Validation: 0.9392 ROC-AUC-income-Test: 0.9386
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9583 ROC-AUC-marital-Test: 0.9569
# Epoch 57/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2275 - income_loss: 0.1293 - marital_loss: 0.0983 - income_acc: 0.9496 - marital_acc: 0.9580 - val_loss: 0.5262 - val_income_loss: 0.1861 - val_marital_loss: 0.3401 - val_income_acc: 0.9462 - val_marital_acc: 0.8734
# ROC-AUC-income-Train: 0.9435 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9557 ROC-AUC-marital-Test: 0.9542
# Epoch 58/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2305 - income_loss: 0.1291 - marital_loss: 0.1013 - income_acc: 0.9504 - marital_acc: 0.9578 - val_loss: 0.5087 - val_income_loss: 0.1871 - val_marital_loss: 0.3216 - val_income_acc: 0.9459 - val_marital_acc: 0.8683
# ROC-AUC-income-Train: 0.9409 ROC-AUC-income-Validation: 0.9349 ROC-AUC-income-Test: 0.9344
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9578 ROC-AUC-marital-Test: 0.9561
# Epoch 59/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2275 - income_loss: 0.1284 - marital_loss: 0.0991 - income_acc: 0.9498 - marital_acc: 0.9576 - val_loss: 0.5625 - val_income_loss: 0.1797 - val_marital_loss: 0.3828 - val_income_acc: 0.9447 - val_marital_acc: 0.8509
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9388 ROC-AUC-income-Test: 0.9383
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9533 ROC-AUC-marital-Test: 0.9516
# Epoch 60/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2242 - income_loss: 0.1272 - marital_loss: 0.0970 - income_acc: 0.9501 - marital_acc: 0.9576 - val_loss: 0.5278 - val_income_loss: 0.1831 - val_marital_loss: 0.3447 - val_income_acc: 0.9445 - val_marital_acc: 0.8635
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9388 ROC-AUC-income-Test: 0.9382
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9533 ROC-AUC-marital-Test: 0.9518
# Epoch 61/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2247 - income_loss: 0.1283 - marital_loss: 0.0964 - income_acc: 0.9506 - marital_acc: 0.9579 - val_loss: 0.5574 - val_income_loss: 0.1996 - val_marital_loss: 0.3578 - val_income_acc: 0.9444 - val_marital_acc: 0.8712
# ROC-AUC-income-Train: 0.9449 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9529 ROC-AUC-marital-Test: 0.9515
# Epoch 62/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2285 - income_loss: 0.1292 - marital_loss: 0.0993 - income_acc: 0.9506 - marital_acc: 0.9576 - val_loss: 0.5094 - val_income_loss: 0.1954 - val_marital_loss: 0.3140 - val_income_acc: 0.9436 - val_marital_acc: 0.8685
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9389 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9924 ROC-AUC-marital-Validation: 0.9558 ROC-AUC-marital-Test: 0.9543
# Epoch 63/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2267 - income_loss: 0.1284 - marital_loss: 0.0982 - income_acc: 0.9503 - marital_acc: 0.9577 - val_loss: 0.5173 - val_income_loss: 0.2144 - val_marital_loss: 0.3029 - val_income_acc: 0.9410 - val_marital_acc: 0.8929
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9379 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9589 ROC-AUC-marital-Test: 0.9573
# Epoch 64/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2277 - income_loss: 0.1298 - marital_loss: 0.0979 - income_acc: 0.9499 - marital_acc: 0.9572 - val_loss: 0.4563 - val_income_loss: 0.1728 - val_marital_loss: 0.2835 - val_income_acc: 0.9430 - val_marital_acc: 0.8966
# ROC-AUC-income-Train: 0.9454 ROC-AUC-income-Validation: 0.9385 ROC-AUC-income-Test: 0.9382
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9609 ROC-AUC-marital-Test: 0.9593
# Epoch 65/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2267 - income_loss: 0.1288 - marital_loss: 0.0979 - income_acc: 0.9501 - marital_acc: 0.9580 - val_loss: 0.4820 - val_income_loss: 0.1959 - val_marital_loss: 0.2862 - val_income_acc: 0.9424 - val_marital_acc: 0.8999
# ROC-AUC-income-Train: 0.9392 ROC-AUC-income-Validation: 0.9331 ROC-AUC-income-Test: 0.9324
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9618 ROC-AUC-marital-Test: 0.9605
# Epoch 66/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2261 - income_loss: 0.1289 - marital_loss: 0.0972 - income_acc: 0.9493 - marital_acc: 0.9576 - val_loss: 0.4951 - val_income_loss: 0.1939 - val_marital_loss: 0.3011 - val_income_acc: 0.9457 - val_marital_acc: 0.8956
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9376
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9608 ROC-AUC-marital-Test: 0.9591
# Epoch 67/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2261 - income_loss: 0.1278 - marital_loss: 0.0983 - income_acc: 0.9504 - marital_acc: 0.9573 - val_loss: 0.4774 - val_income_loss: 0.1811 - val_marital_loss: 0.2963 - val_income_acc: 0.9458 - val_marital_acc: 0.8880
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.9357 ROC-AUC-income-Test: 0.9353
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9605 ROC-AUC-marital-Test: 0.959
# Epoch 68/100
# 199523/199523 [==============================] - 15s 73us/step - loss: 0.2248 - income_loss: 0.1280 - marital_loss: 0.0968 - income_acc: 0.9511 - marital_acc: 0.9574 - val_loss: 0.4770 - val_income_loss: 0.2017 - val_marital_loss: 0.2754 - val_income_acc: 0.9432 - val_marital_acc: 0.9013
# ROC-AUC-income-Train: 0.9454 ROC-AUC-income-Validation: 0.9388 ROC-AUC-income-Test: 0.9383
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9639 ROC-AUC-marital-Test: 0.9625
# Epoch 69/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2252 - income_loss: 0.1284 - marital_loss: 0.0967 - income_acc: 0.9501 - marital_acc: 0.9578 - val_loss: 0.4699 - val_income_loss: 0.1837 - val_marital_loss: 0.2862 - val_income_acc: 0.9450 - val_marital_acc: 0.8938
# ROC-AUC-income-Train: 0.9455 ROC-AUC-income-Validation: 0.9389 ROC-AUC-income-Test: 0.9384
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9605 ROC-AUC-marital-Test: 0.9589
# Epoch 70/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2242 - income_loss: 0.1279 - marital_loss: 0.0963 - income_acc: 0.9511 - marital_acc: 0.9578 - val_loss: 0.5059 - val_income_loss: 0.2019 - val_marital_loss: 0.3040 - val_income_acc: 0.9460 - val_marital_acc: 0.8898
# ROC-AUC-income-Train: 0.9441 ROC-AUC-income-Validation: 0.9376 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.9587 ROC-AUC-marital-Test: 0.9573
# Epoch 71/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2262 - income_loss: 0.1284 - marital_loss: 0.0977 - income_acc: 0.9505 - marital_acc: 0.9576 - val_loss: 0.4629 - val_income_loss: 0.1789 - val_marital_loss: 0.2841 - val_income_acc: 0.9452 - val_marital_acc: 0.9031
# ROC-AUC-income-Train: 0.9451 ROC-AUC-income-Validation: 0.9383 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9935 ROC-AUC-marital-Validation: 0.9635 ROC-AUC-marital-Test: 0.9621
# Epoch 72/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2287 - income_loss: 0.1312 - marital_loss: 0.0975 - income_acc: 0.9505 - marital_acc: 0.9574 - val_loss: 0.4801 - val_income_loss: 0.1973 - val_marital_loss: 0.2827 - val_income_acc: 0.9429 - val_marital_acc: 0.8943
# ROC-AUC-income-Train: 0.9456 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9375
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.9638 ROC-AUC-marital-Test: 0.9624
# Epoch 73/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2238 - income_loss: 0.1277 - marital_loss: 0.0961 - income_acc: 0.9506 - marital_acc: 0.9583 - val_loss: 0.4805 - val_income_loss: 0.2109 - val_marital_loss: 0.2695 - val_income_acc: 0.9451 - val_marital_acc: 0.9034
# ROC-AUC-income-Train: 0.9437 ROC-AUC-income-Validation: 0.9372 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.965 ROC-AUC-marital-Test: 0.9636
# Epoch 74/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2240 - income_loss: 0.1275 - marital_loss: 0.0965 - income_acc: 0.9506 - marital_acc: 0.9579 - val_loss: 0.4910 - val_income_loss: 0.2120 - val_marital_loss: 0.2790 - val_income_acc: 0.9437 - val_marital_acc: 0.9004
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9367 ROC-AUC-income-Test: 0.9366
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9627 ROC-AUC-marital-Test: 0.9614
# Epoch 75/100
# 199523/199523 [==============================] - 15s 74us/step - loss: 0.2241 - income_loss: 0.1284 - marital_loss: 0.0957 - income_acc: 0.9502 - marital_acc: 0.9579 - val_loss: 0.5089 - val_income_loss: 0.2137 - val_marital_loss: 0.2952 - val_income_acc: 0.9421 - val_marital_acc: 0.8963
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9369 ROC-AUC-income-Test: 0.9365
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9603 ROC-AUC-marital-Test: 0.9588
# Epoch 76/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2239 - income_loss: 0.1274 - marital_loss: 0.0965 - income_acc: 0.9506 - marital_acc: 0.9576 - val_loss: 0.4757 - val_income_loss: 0.2247 - val_marital_loss: 0.2510 - val_income_acc: 0.9409 - val_marital_acc: 0.9064
# ROC-AUC-income-Train: 0.9395 ROC-AUC-income-Validation: 0.9314 ROC-AUC-income-Test: 0.9303
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9669 ROC-AUC-marital-Test: 0.9655
# Epoch 77/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2250 - income_loss: 0.1289 - marital_loss: 0.0961 - income_acc: 0.9495 - marital_acc: 0.9576 - val_loss: 0.5625 - val_income_loss: 0.2281 - val_marital_loss: 0.3344 - val_income_acc: 0.9441 - val_marital_acc: 0.8919
# ROC-AUC-income-Train: 0.9431 ROC-AUC-income-Validation: 0.9351 ROC-AUC-income-Test: 0.9346
# ROC-AUC-marital-Train: 0.9934 ROC-AUC-marital-Validation: 0.9618 ROC-AUC-marital-Test: 0.9606
# Epoch 78/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2242 - income_loss: 0.1274 - marital_loss: 0.0968 - income_acc: 0.9510 - marital_acc: 0.9575 - val_loss: 0.4755 - val_income_loss: 0.1937 - val_marital_loss: 0.2818 - val_income_acc: 0.9435 - val_marital_acc: 0.8985
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9377
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9644 ROC-AUC-marital-Test: 0.963
# Epoch 79/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2231 - income_loss: 0.1269 - marital_loss: 0.0962 - income_acc: 0.9506 - marital_acc: 0.9578 - val_loss: 0.4561 - val_income_loss: 0.2010 - val_marital_loss: 0.2552 - val_income_acc: 0.9435 - val_marital_acc: 0.9107
# ROC-AUC-income-Train: 0.9454 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9374
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9701 ROC-AUC-marital-Test: 0.9691
# Epoch 80/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2243 - income_loss: 0.1285 - marital_loss: 0.0958 - income_acc: 0.9503 - marital_acc: 0.9579 - val_loss: 0.4613 - val_income_loss: 0.1806 - val_marital_loss: 0.2807 - val_income_acc: 0.9446 - val_marital_acc: 0.9043
# ROC-AUC-income-Train: 0.944 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.936
# ROC-AUC-marital-Train: 0.9938 ROC-AUC-marital-Validation: 0.965 ROC-AUC-marital-Test: 0.9635
# Epoch 81/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2242 - income_loss: 0.1275 - marital_loss: 0.0967 - income_acc: 0.9507 - marital_acc: 0.9579 - val_loss: 0.4621 - val_income_loss: 0.1876 - val_marital_loss: 0.2745 - val_income_acc: 0.9445 - val_marital_acc: 0.9035
# ROC-AUC-income-Train: 0.9407 ROC-AUC-income-Validation: 0.9346 ROC-AUC-income-Test: 0.9334
# ROC-AUC-marital-Train: 0.9939 ROC-AUC-marital-Validation: 0.967 ROC-AUC-marital-Test: 0.966
# Epoch 82/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2233 - income_loss: 0.1273 - marital_loss: 0.0960 - income_acc: 0.9501 - marital_acc: 0.9578 - val_loss: 0.5106 - val_income_loss: 0.2190 - val_marital_loss: 0.2916 - val_income_acc: 0.9427 - val_marital_acc: 0.8971
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9369
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9622 ROC-AUC-marital-Test: 0.9607
# Epoch 83/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2270 - income_loss: 0.1292 - marital_loss: 0.0978 - income_acc: 0.9501 - marital_acc: 0.9584 - val_loss: 0.4838 - val_income_loss: 0.1890 - val_marital_loss: 0.2948 - val_income_acc: 0.9443 - val_marital_acc: 0.8951
# ROC-AUC-income-Train: 0.9433 ROC-AUC-income-Validation: 0.9364 ROC-AUC-income-Test: 0.9365
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9629 ROC-AUC-marital-Test: 0.9613
# Epoch 84/100
# 199523/199523 [==============================] - 15s 77us/step - loss: 0.2246 - income_loss: 0.1286 - marital_loss: 0.0960 - income_acc: 0.9495 - marital_acc: 0.9577 - val_loss: 0.4670 - val_income_loss: 0.1905 - val_marital_loss: 0.2765 - val_income_acc: 0.9453 - val_marital_acc: 0.8972
# ROC-AUC-income-Train: 0.9424 ROC-AUC-income-Validation: 0.9359 ROC-AUC-income-Test: 0.9348
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9639 ROC-AUC-marital-Test: 0.9625
# Epoch 85/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2247 - income_loss: 0.1279 - marital_loss: 0.0968 - income_acc: 0.9500 - marital_acc: 0.9584 - val_loss: 0.4595 - val_income_loss: 0.1940 - val_marital_loss: 0.2655 - val_income_acc: 0.9448 - val_marital_acc: 0.9025
# ROC-AUC-income-Train: 0.9453 ROC-AUC-income-Validation: 0.9382 ROC-AUC-income-Test: 0.9378
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9632 ROC-AUC-marital-Test: 0.9618
# Epoch 86/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2294 - income_loss: 0.1290 - marital_loss: 0.1003 - income_acc: 0.9510 - marital_acc: 0.9582 - val_loss: 0.4672 - val_income_loss: 0.2099 - val_marital_loss: 0.2572 - val_income_acc: 0.9429 - val_marital_acc: 0.9059
# ROC-AUC-income-Train: 0.9442 ROC-AUC-income-Validation: 0.937 ROC-AUC-income-Test: 0.9366
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.967 ROC-AUC-marital-Test: 0.9656
# Epoch 87/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2247 - income_loss: 0.1282 - marital_loss: 0.0965 - income_acc: 0.9500 - marital_acc: 0.9586 - val_loss: 0.4545 - val_income_loss: 0.2112 - val_marital_loss: 0.2434 - val_income_acc: 0.9428 - val_marital_acc: 0.9084
# ROC-AUC-income-Train: 0.9456 ROC-AUC-income-Validation: 0.9385 ROC-AUC-income-Test: 0.938
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9682 ROC-AUC-marital-Test: 0.967
# Epoch 88/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2250 - income_loss: 0.1265 - marital_loss: 0.0985 - income_acc: 0.9509 - marital_acc: 0.9580 - val_loss: 0.4733 - val_income_loss: 0.1914 - val_marital_loss: 0.2819 - val_income_acc: 0.9445 - val_marital_acc: 0.9089
# ROC-AUC-income-Train: 0.946 ROC-AUC-income-Validation: 0.9393 ROC-AUC-income-Test: 0.9391
# ROC-AUC-marital-Train: 0.9928 ROC-AUC-marital-Validation: 0.9655 ROC-AUC-marital-Test: 0.9643
# Epoch 89/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2225 - income_loss: 0.1261 - marital_loss: 0.0964 - income_acc: 0.9511 - marital_acc: 0.9572 - val_loss: 0.4728 - val_income_loss: 0.2099 - val_marital_loss: 0.2628 - val_income_acc: 0.9423 - val_marital_acc: 0.9007
# ROC-AUC-income-Train: 0.9463 ROC-AUC-income-Validation: 0.9397 ROC-AUC-income-Test: 0.9396
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9636 ROC-AUC-marital-Test: 0.9617
# Epoch 90/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2233 - income_loss: 0.1267 - marital_loss: 0.0966 - income_acc: 0.9509 - marital_acc: 0.9577 - val_loss: 0.4870 - val_income_loss: 0.1901 - val_marital_loss: 0.2968 - val_income_acc: 0.9416 - val_marital_acc: 0.8999
# ROC-AUC-income-Train: 0.9443 ROC-AUC-income-Validation: 0.9369 ROC-AUC-income-Test: 0.9372
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.9635 ROC-AUC-marital-Test: 0.9624
# Epoch 91/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2220 - income_loss: 0.1268 - marital_loss: 0.0952 - income_acc: 0.9510 - marital_acc: 0.9583 - val_loss: 0.4815 - val_income_loss: 0.1978 - val_marital_loss: 0.2837 - val_income_acc: 0.9452 - val_marital_acc: 0.9020
# ROC-AUC-income-Train: 0.946 ROC-AUC-income-Validation: 0.9398 ROC-AUC-income-Test: 0.9394
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9649 ROC-AUC-marital-Test: 0.9637
# Epoch 92/100
# 199523/199523 [==============================] - 15s 75us/step - loss: 0.2222 - income_loss: 0.1263 - marital_loss: 0.0959 - income_acc: 0.9515 - marital_acc: 0.9578 - val_loss: 0.4423 - val_income_loss: 0.1735 - val_marital_loss: 0.2687 - val_income_acc: 0.9437 - val_marital_acc: 0.9032
# ROC-AUC-income-Train: 0.9448 ROC-AUC-income-Validation: 0.939 ROC-AUC-income-Test: 0.9391
# ROC-AUC-marital-Train: 0.9941 ROC-AUC-marital-Validation: 0.9666 ROC-AUC-marital-Test: 0.9653
# Epoch 93/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2233 - income_loss: 0.1275 - marital_loss: 0.0958 - income_acc: 0.9508 - marital_acc: 0.9580 - val_loss: 0.4847 - val_income_loss: 0.1821 - val_marital_loss: 0.3026 - val_income_acc: 0.9433 - val_marital_acc: 0.8993
# ROC-AUC-income-Train: 0.9444 ROC-AUC-income-Validation: 0.9347 ROC-AUC-income-Test: 0.934
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.962 ROC-AUC-marital-Test: 0.9605
# Epoch 94/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2215 - income_loss: 0.1265 - marital_loss: 0.0951 - income_acc: 0.9518 - marital_acc: 0.9582 - val_loss: 0.4512 - val_income_loss: 0.1808 - val_marital_loss: 0.2704 - val_income_acc: 0.9442 - val_marital_acc: 0.9001
# ROC-AUC-income-Train: 0.9445 ROC-AUC-income-Validation: 0.9378 ROC-AUC-income-Test: 0.9382
# ROC-AUC-marital-Train: 0.9937 ROC-AUC-marital-Validation: 0.964 ROC-AUC-marital-Test: 0.9628
# Epoch 95/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2237 - income_loss: 0.1270 - marital_loss: 0.0967 - income_acc: 0.9512 - marital_acc: 0.9579 - val_loss: 0.4756 - val_income_loss: 0.1821 - val_marital_loss: 0.2935 - val_income_acc: 0.9421 - val_marital_acc: 0.8869
# ROC-AUC-income-Train: 0.9461 ROC-AUC-income-Validation: 0.9384 ROC-AUC-income-Test: 0.9394
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9611 ROC-AUC-marital-Test: 0.9596
# Epoch 96/100
# 199523/199523 [==============================] - 15s 77us/step - loss: 0.2205 - income_loss: 0.1256 - marital_loss: 0.0949 - income_acc: 0.9515 - marital_acc: 0.9584 - val_loss: 0.4760 - val_income_loss: 0.1852 - val_marital_loss: 0.2908 - val_income_acc: 0.9442 - val_marital_acc: 0.8930
# ROC-AUC-income-Train: 0.9421 ROC-AUC-income-Validation: 0.9355 ROC-AUC-income-Test: 0.9361
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9629 ROC-AUC-marital-Test: 0.9614
# Epoch 97/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2230 - income_loss: 0.1270 - marital_loss: 0.0960 - income_acc: 0.9514 - marital_acc: 0.9574 - val_loss: 0.4656 - val_income_loss: 0.1857 - val_marital_loss: 0.2799 - val_income_acc: 0.9419 - val_marital_acc: 0.9036
# ROC-AUC-income-Train: 0.9438 ROC-AUC-income-Validation: 0.9361 ROC-AUC-income-Test: 0.9367
# ROC-AUC-marital-Train: 0.994 ROC-AUC-marital-Validation: 0.9651 ROC-AUC-marital-Test: 0.9637
# Epoch 98/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2215 - income_loss: 0.1256 - marital_loss: 0.0960 - income_acc: 0.9514 - marital_acc: 0.9579 - val_loss: 0.4714 - val_income_loss: 0.1874 - val_marital_loss: 0.2840 - val_income_acc: 0.9454 - val_marital_acc: 0.8999
# ROC-AUC-income-Train: 0.945 ROC-AUC-income-Validation: 0.9377 ROC-AUC-income-Test: 0.9389
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.9641 ROC-AUC-marital-Test: 0.9626
# Epoch 99/100
# 199523/199523 [==============================] - 15s 77us/step - loss: 0.2219 - income_loss: 0.1264 - marital_loss: 0.0955 - income_acc: 0.9512 - marital_acc: 0.9585 - val_loss: 0.4647 - val_income_loss: 0.1955 - val_marital_loss: 0.2692 - val_income_acc: 0.9433 - val_marital_acc: 0.9019
# ROC-AUC-income-Train: 0.9463 ROC-AUC-income-Validation: 0.9389 ROC-AUC-income-Test: 0.9393
# ROC-AUC-marital-Train: 0.9942 ROC-AUC-marital-Validation: 0.963 ROC-AUC-marital-Test: 0.9618
# Epoch 100/100
# 199523/199523 [==============================] - 15s 76us/step - loss: 0.2229 - income_loss: 0.1252 - marital_loss: 0.0977 - income_acc: 0.9511 - marital_acc: 0.9586 - val_loss: 0.4897 - val_income_loss: 0.1851 - val_marital_loss: 0.3046 - val_income_acc: 0.9454 - val_marital_acc: 0.9009
# ROC-AUC-income-Train: 0.9452 ROC-AUC-income-Validation: 0.9389 ROC-AUC-income-Test: 0.9387
# ROC-AUC-marital-Train: 0.9943 ROC-AUC-marital-Validation: 0.9622 ROC-AUC-marital-Test: 0.9608
